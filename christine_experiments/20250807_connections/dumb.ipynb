# %%
# %load_ext autoreload
# %autoreload 2

from inspect_others.inspect_utils import extract_scores_from_log
from inspect_ai.log import EvalLog, read_eval_log

log_file = 'christine_experiments/20250807_connections/connections_train/claude-sonnet-4/logs/2025-08-07T19-23-25-07-00_nyt-connections_VrZncxH5zYVySWYvoAH9R2.eval'

log = read_eval_log(log_file)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from inspect_others.inspect_utils import save_transcripts
from pathlib import Path
from inspect_ai.log import EvalLog, read_eval_log

save_transcripts(log, save_dir = Path('./christine_experiments/20250807_connections/connections_train/claude-sonnet-4'), dataset_name='nyt-connections')
# Out:
# Saving transcripts to christine_experiments/20250807_connections/connections_train/claude-sonnet-4/nyt-connections_transcripts.jsonl
# ✓ Transcripts saved to: christine_experiments/20250807_connections/connections_train/claude-sonnet-4/nyt-connections_transcripts.jsonl
# PosixPath('christine_experiments/20250807_connections/connections_train/claude-sonnet-4/nyt-connections_transcripts.jsonl')

# %%
log_file = './christine_experiments/20250807_connections/connections_test/claude-sonnet-4/logs/2025-08-07T22-04-27-07-00_nyt-connections_BKtHgCYwuZSRvr4mMMFzHE.eval'

log = read_eval_log(log_file)

# %%
save_transcripts(log, save_dir = Path('./christine_experiments/20250807_connections/connections_test/claude-sonnet-4'), dataset_name='nyt-connections')
# Out:
# Saving transcripts to christine_experiments/20250807_connections/connections_test/claude-sonnet-4/nyt-connections_transcripts.jsonl
# ✓ Transcripts saved to: christine_experiments/20250807_connections/connections_test/claude-sonnet-4/nyt-connections_transcripts.jsonl
# PosixPath('christine_experiments/20250807_connections/connections_test/claude-sonnet-4/nyt-connections_transcripts.jsonl')
