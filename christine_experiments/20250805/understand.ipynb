# %%
from inspect_ai.log import read_eval_log

# %%
log = read_eval_log('inspect_others/results/gpt-4.1/logs/2025-08-05T15-09-55-07-00_mmlu-pro_Zq9WNxzC6XhLn9qt8bBjAN.eval')

# %%
log.results.scores[0].name
# Out:
# 'choice'

# %%
from inspect_others.inspect_utils import extract_scores_from_log

# %%
extract_scores_from_log(log)
# Out:
# {'model': 'openai/gpt-4.1',
#  'total_samples': 500,
#  'completed_samples': 500,
#  'choice': {'accuracy': 0.804,
#   'stderr': 0.017770751227744897,
#   'scorer': 'choice'}}
